# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# 👋 **¡Hola! Soy Dot, tu revisor de IA.**
#
# He completado la primera revisión de tu código. A continuación, encontrarás mis comentarios y sugerencias de mejora.
#
# **¿Qué debes hacer ahora?**
#
# 1. **Revisar:** Lee mis comentarios en el notebook más abajo.
# 2. **Decidir:**
# * **¿Estás de acuerdo con el feedback?** ¡Genial! Actualiza tu código según las sugerencias.
# * **¿No estás de acuerdo o crees que es un error?** ¡No hay problema! Puedes dejar tu código exactamente como está.
#
#
# 3. **Volver a enviar:** Envía tu proyecto de nuevo. **Tu próxima iteración será revisada por un experto humano**, independientemente de si hiciste cambios o no.
#
# -------------------------------------------------------------------------------------------------------------
# Mis comentarios están más abajo. **Te pido amablemente que no los muevas, modifiques ni elimines**.
#
# Verás mis comentarios resaltados en cuadros verdes, amarillos o rojos como estos:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Correcto. Todo se ha hecho exitosamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones.
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # ¡Hola Cobos!
#
# Mi nombre es Sofia Arboleda, estaré ayudándote a revisar este proyecto para que quede en su mejor versión. Corregiré algunas imprecisiones de la review de Dot y te dejaré mis propias recomendaciones o felicitaciones.
#
# Un gusto acompañarte en este proceso, vamos a ello!
#
# ### Comentario General Iteración #2
#
# Quiero dejarte aqui la apreciacion general del proyecto para que sepas en lo que debes enfocarte y luego vas punto por punto revisando mis recomendaciones.
#
# Respecto a tu trabajo en esta segunda iteración, felicitarte porque has mostrado tus conocimientos de la mejor forma, utilizando los metodos correctamente, realizando filtros de forma sencilla y trabajando con los diferentes datasets para llegar a las respuestas de negocio que se buscaban en este proyecto. Solo quedan algunas recomendaciones de mejora que te servirán para mejorar tus entregas a futuro y corregir el desarrollo.
#
# Sigue aprendiendo bastante en este camino, excelente trabajo!
# </div>

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
# Primero cargaremos las librerias pandas y matplotlib.
# Con el método pd.read_csv() leeré cada archivo y lo guardare en orders, products, aisles, departments y order_producs. Pero los archivos no estan separados por comas, estan separados por punto y como ";", así que ocuparemos el parametro sep = ";".
# Tenemos datos faltantes y ordenes duplicadas.

# %%
# importar librerías
import pandas as pd
from matplotlib import pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
orders = pd.read_csv('/datasets/instacart_orders.csv', sep = ";")
products = pd.read_csv('/datasets/products.csv', sep = ";")
aisles = pd.read_csv('/datasets/aisles.csv', sep = ";")
departments = pd.read_csv('/datasets/departments.csv', sep = ";")
order_products = pd.read_csv('/datasets/order_products.csv', sep = ";")

# %%
# mostrar información del DataFrame
print("INSTACART ORDERS")
print(orders.head())

print(orders.info())

print()
# Out:
# INSTACART ORDERS
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
# ...

# %%
# mostrar información del DataFrame

print("PRODUCTS")
print(products.head())
print(products.info())
print()
# Out:
# PRODUCTS
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# ...

# %%
# mostrar información del DataFrame

print("AISLES")

print(aisles.head())
print(aisles.info())
print()
# Out:
# AISLES
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None

# %%
# mostrar información del DataFrame

print("DEPARTMENTS")
print(departments.head())
print(departments.info())
print()
# Out:
# DEPARTMENTS
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# None

# %%
# mostrar información del DataFrame

print("ORDER PRODUCTS")
print(order_products.head())
print(order_products.info(show_counts = True))
# Out:
# ORDER PRODUCTS
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None

# %% [markdown]
# ## Conclusiones
#
# La mayoria de los data frame tienen valores austentes, pero ninguno que afecte las "ordenes".
#
# En orders:
#     La única columna que tiene datos ausentes es la columna de "days_since_prior_order", también es la única que no tiene formato entero, sino flotante, (debe ser entero, ya que la unidad son días enteros)
#
# En products:
#     Solo tenemos datos faltantes en la columna "product_name". Y sus formatos tienen consistencia.
#
# En aisles:
#     Todo bien (a priori)
#
# En departments:
#     Todo bien (a prior)
#
# En order_products:
#     Tenemos datos nulos en add_to_cart_order

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Buen trabajo de revisión inicial de los datos. Aplicaste correctamente los métodos requeridos. Genial en el caso del dataset `order_products` usando `show_counts=True`.
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Primero revisaré y corregiré los tipos de datos.
# Verificaré la existencia de datos faltantes (como en dias desde la última compra), que tendría sentido, ya que los primeros usuarios no tendrían esa información.
# Y trataré los datos repetidos, verificaré si tiene sentido eliminarlos, o si pierdo información al eliminarlos.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
print("Cantidad de filas duplicadas:", orders.duplicated().sum())
print(orders[orders.duplicated()])
# Out:
# Cantidad de filas duplicadas: 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
#
# Si las hay, son 15.
# Lo único visible - destacable a priori es que el día es el mismo (3 miercoles), y la hora es 2. Pero si toda la fila es igual, entonces comparté el mismo id del pedido, es decir, es el mismo pedido. Por lo que no pierdo información al eliminarlos.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
print(orders[(orders["order_dow"] == 3) & (orders["order_hour_of_day"] == 2)].head(20))
orders[(orders["order_dow"] == 3) & (orders["order_hour_of_day"] == 2)].info()
# Out:
#        order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838    2766110   162084            41          3                  2
# 5156    2190225   138285            18          3                  2
# 15506    553049    58599            13          3                  2
# 18420    382357   120200            19          3                  2
# 24691    690242    77357             2          3                  2
# 25376   1378085    75705            21          3                  2
# 26301   2846262   176827             2          3                  2
# 29129    353088    46038             4          3                  2
# 30371   1918001   188546            14          3                  2
# 31404   1725788   147843            10          3                  2
# 48024   1453300    69262            27          3                  2
# 52245   2851380   118608            33          3                  2
# 62357   1399416    93151            34          3                  2
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# Que los datos duplicados son solo eso, "duplicados". Ya que compartirian el mismo numero de orden.
# El miercoles a las 2 se hicieron 121 pedidos. De los cuales 15 se duplicaron.

# %%
# Elimina los pedidos duplicados
orders.drop_duplicates( inplace = True)

# %%
# Vuelve a verificar si hay filas duplicadas
orders.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
orders["order_id"].duplicated().sum()
# Out:
# 0

# %%
#Creo que más adelante no se hizo el cambio en el tipo de datos. Así que lo hice aquí.
orders["days_since_prior_order"] = orders["days_since_prior_order"].astype("Int64")

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Quitamos los datos duplicados, porque nos dimos cuenta que no nos daban información adicional. (tambien cambie el tipo de dato de la columna de días faltantes)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Hiciste una correcta eliminación de los duplicados.

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
products.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay ID de productos duplicados
products["product_id"].duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
products["product_name"].str.upper().duplicated().sum()
# Out:
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
products["product_name"].dropna().str.upper().duplicated().sum()
# Out:
# 104

# %%
#Revisar si esos 104 tienen id distino
products["product_name"] = products["product_name"].str.upper()
products["product_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Tengo 1361 nombres duplicados pero en la mayoria no tengo el nombre del productos, ya que eliminando los nombres faltantes de productos, entonces solo me quedan 104 nombres. Pero esos 104 tienen id distinto, por lo que son productos distintos, así que no los modificaré.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Hiciste un buen trabajo al no eliminar estos valores duplicados por nombre, ya que al tener el mismo nombre pero diferentes IDs puede tratarse de productos con diferentes ubicaciones o productos completamente diferentes nombrados de forma erronea.
#
# Excelente trabajo con la correccion de mayusculas, caracteres especiales y espacios.

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
departments.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
departments["department_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No hay duplicados absolutos, ni por columna

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo comprobando tanto las filas completamente duplicadas como los valores duplicados de `department_id` y resumiendo el resultado con claridad; esto constituye una verificación completa de duplicados para la tabla de departments.
#
# </div>

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
aisles.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
aisles["aisle_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No hay duplicados absolutos, ni por columna

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
order_products.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
print(order_products["order_id"].duplicated().sum())
print(order_products[["order_id", "product_id"]].duplicated().sum())
# Out:
# 4094961
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Parece que no hay duplicados. Porque tiene sentido que el ID de la orden se repita, pues aparece una vez por cada producto del pedido.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Excelente trabajo con las tablas `departments`, `aisles` y `order_products`.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
print("Cantidad de Valores Ausentes: ", products["product_name"].isna().sum())
print(products[products["product_name"].isna()])
# Out:
# Cantidad de Valores Ausentes:  1258
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Ya se habia notado que muchos nombres de productos faltan, hay 1258 nombres ausentes. Parece que todos son del pasillo 100 departamento 21

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
print(products[(products["product_name"].isna()) & (products["aisle_id"] == 100)])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Efectivamente, en el pasillo 100 se encuentran todos los nombres de productos faltantes.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
print(products[(products["product_name"].isna()) & (products["department_id"] == 21)])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Si, este filtro tiene exactamente la cantidad de valores ausentes en el nombre del productos. (es decir,el pasillo contiene todos los valores ausentes de esa columna)

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
print(aisles.query("aisle_id == 100"))
print()
print(departments.query("department_id == 21"))
# Out:
#     aisle_id    aisle
# 99       100  missing
#
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Es un departamento y un pasillo sin nombre. No esta en formato NaN. Tienen otro formato. Pero es un pasiilo y un departamento que no "tenemos".

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products["product_name"].fillna("Unknown", inplace = True)
print(products["product_name"].unique())
# Out:
# ['CHOCOLATE SANDWICH COOKIES' 'ALL-SEASONS SALT'
#  'ROBUST GOLDEN UNSWEETENED OOLONG TEA' ... 'ARTISAN BAGUETTE'
#  'SMARTBLEND HEALTHY METABOLISM DRY CAT FOOD' 'FRESH FOAMING CLEANSER']

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# 1258 filas fueron completadas con "Unknown" en la columna del nombre del producto. Tiene sentido conservarlas, porque son pedidos hechos, y por ejemplo, aportan información sobre la cantidad de productos, etc. Aunque nos falte información de lo que es. Aunque supongo que depednera del analisis que se desee.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Muy bien! Hiciste un buen trabajo al ahondar en los datos ausentes y su correspondencia con las tablas de pasillos y departamentos. Hiciste el correcto reemplazo de valores ausentes.

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print("Cantidad de valores ausentes por columna", orders.isna().sum())
print()
print(orders[orders.isna().any(axis = 1)])
# Out:
# Cantidad de valores ausentes por columna order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64
#
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# ...

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
print(orders[(orders.isna().any(axis=1)) & (orders["order_number"] != 1)])
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
orders.fillna(0, inplace = True)
print("Cantidad de valores ausentes por columna", orders.isna().sum())
# Out:
# Cantidad de valores ausentes por columna order_id                  0
# user_id                   0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No hay otros datos ausentes en filas de clientes que NO compren por primera vez. Por lo que considero razonable cambiar esos datos ausentes por un 0. (Ya que mo hay dias antes de su última compra)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Excelente. Encontraste que si se encuentran ordenes que sean el primer pedido del cliente, es normal que no tengamos información sobre cuántos días han pasado desde su último pedido (days_since_prior_order), por lo cual son filas que se mantienen sin cambios.

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(order_products.isna().sum())
print()
print(order_products[order_products.isna().any(axis=1)])
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64
#
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print( "Los valores min y max del orden secuancial", order_products["add_to_cart_order"].min(), order_products["add_to_cart_order"].max())
# Out:
# Los valores min y max del orden secuancial 1.0 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# la maxima cantidad de productos que se han pedido en una orden es 64. Puede ser que 64 sea un límite sobre la cantidad de productos a los que les "guarda" su posición de compra. Ya que los todos los datos faltantes son de la columna de conteo.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
Nan_add_to_cart_order = order_products[order_products["add_to_cart_order"].isna()]
print(Nan_add_to_cart_order["order_id"])
# Out:
# 737        2449164
# 9926       1968313
# 14394      2926893
# 16418      1717990
# 30114      1959075
#             ...
# 4505662    1800005
# 4511400    1633337
# 4517562     404157
# 4534112    1673227
# 4535739    1832957
# Name: order_id, Length: 836, dtype: int64

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
a = Nan_add_to_cart_order.groupby("order_id").count()
print("Cantidad de pedidos (hipoteticamente) despues de 64: ", a)
print()
orders_with_na = order_products[order_products["order_id"].isin(Nan_add_to_cart_order["order_id"])]
b = orders_with_na.groupby("order_id").count()
print("Cantidad de pedidos totales de ordenes con valores ausentes: ", b)
# Out:
# Cantidad de pedidos (hipoteticamente) despues de 64:            product_id  add_to_cart_order  reordered
# order_id
# 9310               1                  0          1
# 61355             63                  0         63
# 102236            31                  0         31
# 129627             5                  0          5
# 165801             6                  0          6
# ...              ...                ...        ...
# 2999801            6                  0          6
# 3125735           22                  0         22
# 3308010           51                  0         51
# 3347453            7                  0          7
# 3383594            5                  0          5
#
# [70 rows x 3 columns]
#
# Cantidad de pedidos totales de ordenes con valores ausentes:            product_id  add_to_cart_order  reordered
# order_id
# 9310              65                 64         65
# 61355            127                 64        127
# ...

# %%
print((a["product_id"] != (b["product_id"]-b["add_to_cart_order"])).sum())
# Out:
# 0

# %%
print(b["product_id"].min())
# Out:
# 65

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Todas las ordenes con Na, tienen mas de 64 pedidos, (pero sin valor ausente en add_to_cart_order llegan hasta 64). Y revisando la diferentecia entre la cantidad de pedios - 64 (el total de pedidos sin contar na)) coincide con la cantidad de na por fila, para todas con valores ausentes.
# Por lo que despues de 64 productos, se deja de registrar su posicion.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order_products["add_to_cart_order"].fillna(999, inplace = True)
order_products["add_to_cart_order"] = order_products["add_to_cart_order"].astype("int")

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Puede ser que después del producto 64 ya no se registraran más el orden. Se llego a esa conclución revisnando el maximo de la columna, contando la cantidad de productos por pedidos de otra forma. Y consolidando nuestra hipotesis.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Buen trabajo, encontraste que al parecer solo se detecta los primeros 64 productos que se agregan al carrito y si se agregan más productos, deja de registrar el orden correctamente y esos valores aparecen como ausentes.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
# Quitamos los duplicados, y llenamos los valores ausentes con lo creímos mas coherente. (Aunque sigo teniendo duda en la falta de nombre en el pasillo y departamento, ya que si no tengo ninguno de los 3 valores, tengo la información de "una venta", pero no la puedo catalogar en su departamento. No sé si sería ruido que debo eliminar)

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print("Rango de hora del pedido", orders["order_hour_of_day"].min(), orders["order_hour_of_day"].max())
# Out:
# Rango de hora del pedido 0 23

# %%
print("Rango del dia del pedido", orders["order_dow"].min(), orders["order_dow"].max())
# Out:
# Rango del dia del pedido 0 6

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo al validar que `order_hour_of_day` abarca 0–23 y `order_dow` abarca 0–6, y al confirmar claramente que los rangos son razonables.
#
# </div>

# %% [markdown]
# Tengo 24 horas y 7 días. Es razonable

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
hours = orders.groupby("order_hour_of_day")["order_id"].count() 
print(hours)

hours.plot(kind="bar")
plt.title("Número de pedidos por hora del día")
plt.xlabel("Hora del día")
plt.ylabel("Número de pedidos")

plt.show()
# Out:
# order_hour_of_day
# 0      3180
# 1      1763
# 2       989
# 3       770
# 4       765
# 5      1371
# 6      4215
# 7     13043
# 8     25024
# 9     35896
# 10    40578
# 11    40032
# 12    38034
# 13    39007
# 14    39631
# 15    39789
# 16    38112
# 17    31930
# 18    25510
# 19    19547
# 20    14624
# 21    11019
# 22     8512
# 23     5611
# Name: order_id, dtype: int64

# %% [markdown]
# El mayor numero de pedidos es entre el desayuno y la comida. U horas laborales. Entre las 8 y las 18 horas.

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
days = orders.groupby("order_dow")["order_id"].count() 
print(days)
days.plot(kind="bar")
plt.title("Número de pedidos por dia de la semana")
plt.xlabel("Día de la Semana")
plt.ylabel("Número de pedidos")

plt.show()
# Out:
# order_dow
# 0    84090
# 1    82185
# 2    65833
# 3    60897
# 4    59810
# 5    63488
# 6    62649
# Name: order_id, dtype: int64

# %% [markdown]
# Los días con mayor compras son los domingos y lunes (la mayoria de personas compran víveres esos días. Probablemente si dia de pago sea el sabado)

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
print("Promedio de días entre pedidos:", orders["days_since_prior_order"].mean())
print("Mínimo de días entre pedidos:", orders["days_since_prior_order"].min())
print("Máximo de días entre pedidos:", orders["days_since_prior_order"].max())


orders["days_since_prior_order"].hist(bins=31) 
plt.title("Distribución del tiempo de espera entre pedidos")
plt.xlabel("Días desde el pedido anterior")
plt.ylabel("Número de pedidos")

plt.show()
# Out:
# Promedio de días entre pedidos: 10.43385349680135
# Mínimo de días entre pedidos: 0
# Máximo de días entre pedidos: 30

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta tarea pide un gráfico de la distribución de `days_since_prior_order`, pero solo imprimiste estadísticas resumidas. Por favor, agrega un histograma/gráfico de barras (con ejes/título etiquetados y `plt.show()`), y luego comenta sobre el mínimo/máximo en el contexto de la distribución.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# Hay un promedio de 11 días entre un pedidio y otro. Con un minimo del 0 días, (dos compras el mismo día), y un maximo de 30 días ( un mes).
# Gracias al diagrama podemos ver que tenemos un incremento en el dia 30.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Excelente! Los gráficos que presentas muestran claramente cada una de las mediciones solicitadas, tienen una buena presentación de ejes y etiquetado correcto. Tus conclusiones son muy buenas, respecto a las horas y los días en que los usuarios hacen mayores compras.

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
orders[orders["order_dow"] == 3]["order_hour_of_day"].value_counts().sort_index().plot(kind = "bar", label = "Miercoles")
orders[orders["order_dow"] == 6]["order_hour_of_day"].value_counts().sort_index().plot(kind = "bar", alpha=0.6, label="Sábado")

plt.title("Comparación de los Miercoles y Sabado en los pedios por hora")
plt.xlabel("Hora del día")
plt.ylabel("Número de pedidos")
plt.legend()

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Tienen una distribucíon realmente muy parecida. Pero el sabado presenta un aumento entre las 11 y las 15

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Bien hecho: graficaste Wednesday y Saturday en la misma figura con etiquetas/leyenda claras y proporcionaste una interpretación concisa (el repunte del mediodía del Saturday) basada en el gráfico.
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
a = orders.groupby("user_id")["order_id"].count()
a.value_counts().sort_index().plot(kind ="bar")

plt.title("Distribución del número de pedidos por cliente")
plt.xlabel("Número de pedidos")
plt.ylabel("Número de clientes")
#plt.yscale("log")

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La gráfica responde a la pregunta, pero es difícil de leer debido a la gran cantidad de barras. Considera limitar el rango de x (p. ej., hasta un percentil alto de los conteos de pedidos) o usar una escala logarítmica para que la forma de la distribución sea más fácil de interpretar.
#
# </div>

# %% [markdown]
# tiene sentido que haya más usuarios nuevos o que solo tienen pocos pedidos. (Bueno, solo si la aplicación es nueva). Ya que de otra forma, no es un buen servicio. Ya que las personas "dejan" de ocuparlo al rededor del cuarto y quinto pedido. (La distrivución tienen un sesgo positivo, a la derecha), pero se debe a que son los datos extremos, que no puedo tener del lado izquierdo, ya que no hay pedidos negativos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Por favor, amplía esta interpretación para hacer referencia a lo que el gráfico realmente muestra (p. ej., dónde se concentra la mayoría de los clientes, con qué rapidez disminuyen los recuentos y si existe una cola larga/outliers), en lugar de una afirmación general.
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
popular_products = (order_products.groupby("product_id")["order_id"].count().sort_values(ascending = False))
b=popular_products.head(20)
b
# Out:
# product_id
# 24852    66050
# 13176    53297
# 21137    37039
# 21903    33971
# 47209    29773
# 47766    24689
# 47626    21495
# 16797    20018
# 26209    19690
# 27845    19600
# 27966    19197
# 22935    15898
# 24964    15292
# 45007    14584
# 39275    13879
# 49683    13675
# 28204    12544
# 5876     12232
# 8277     11993
# 40706    11781
# Name: order_id, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Aquí calculaste correctamente los 20 principales IDs de producto, pero la tarea requiere mostrar tanto `product_id` como `product_name` en el resultado final presentado. Asegúrate de que la salida que presentes para esta pregunta sea la tabla combinada (no solo IDs/conteos).
#
# </div>

# %%
print(b.reset_index().merge(products[["product_id", "product_name"]], on = "product_id")[["product_id", "product_name"]])
# Out:
#     product_id              product_name
# 0        24852                    BANANA
# 1        13176    BAG OF ORGANIC BANANAS
# 2        21137      ORGANIC STRAWBERRIES
# 3        21903      ORGANIC BABY SPINACH
# 4        47209      ORGANIC HASS AVOCADO
# 5        47766           ORGANIC AVOCADO
# 6        47626               LARGE LEMON
# 7        16797              STRAWBERRIES
# 8        26209                     LIMES
# 9        27845        ORGANIC WHOLE MILK
# 10       27966       ORGANIC RASPBERRIES
# 11       22935      ORGANIC YELLOW ONION
# 12       24964            ORGANIC GARLIC
# 13       45007          ORGANIC ZUCCHINI
# 14       39275       ORGANIC BLUEBERRIES
# 15       49683            CUCUMBER KIRBY
# 16       28204        ORGANIC FUJI APPLE
# 17        5876             ORGANIC LEMON
# 18        8277  APPLE HONEYCRISP ORGANIC
# 19       40706    ORGANIC GRAPE TOMATOES

# %% [markdown]
# Escribe aquí tus conclusiones
# Son productos organicos, y la mayoria son frutas. Por lo que tambien tiene sentido

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Vamos por partes:
# - En la parte B1 hiciste correctamente la comparacion entre los dias miercoles y sabado, reconociendo como los picos de un dia son mas bajos en el otro. Muy buen uso del histograma combinando ambos datos con diferenciador por color.
# - En el inciso B2 hiciste un buen uso del histograma, concluyendo correctamente sobre los habitos de los usuarios.
# - En el inciso B3 hiciste un excelente uso de `merge` para obtener el top de productos con sus identificadores y nombres.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
prod_por_orden = order_products.groupby("order_id")["product_id"].count()

# %%
prod_por_orden.plot(
    kind="hist",
    bins=30
)

plt.title("Distribución del número de artículos por pedido")
plt.xlabel("Número de artículos")
plt.ylabel("Número de pedidos")

plt.show()

prod_por_orden.plot(kind = "box")
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# Por pedido, la mayoria de los usarios compra menos de 20 productos.
# Y el maximo son aproximadamente 35, el resto son valores atipicos. Y tenemos una mediana de aproximadamente 11.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta conclusión no responde a la pregunta basándose en tu distribución de artículos por pedido, y la afirmación sobre “first purchases” no está respaldada por este gráfico. Considera resumir la distribución (rango típico/más común, una medida de centro como la mediana/media si la calculas, asimetría a la derecha/cola larga) y mencionar cualquier valor atípico notable.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
reordered = order_products[order_products["reordered"] == 1]
top_reordered = (
    reordered.groupby("product_id")["order_id"]
    .count()
    .sort_values(ascending=False)
    .head(20)
    .reset_index(name="times_reordered")
    .merge(
        products[["product_id", "product_name"]],
        on="product_id" 
    )
)

print(top_reordered)
# Out:
#     product_id  times_reordered              product_name
# 0        24852            55763                    BANANA
# 1        13176            44450    BAG OF ORGANIC BANANAS
# 2        21137            28639      ORGANIC STRAWBERRIES
# 3        21903            26233      ORGANIC BABY SPINACH
# 4        47209            23629      ORGANIC HASS AVOCADO
# 5        47766            18743           ORGANIC AVOCADO
# 6        27845            16251        ORGANIC WHOLE MILK
# 7        47626            15044               LARGE LEMON
# 8        27966            14748       ORGANIC RASPBERRIES
# 9        16797            13945              STRAWBERRIES
# 10       26209            13327                     LIMES
# 11       22935            11145      ORGANIC YELLOW ONION
# 12       24964            10411            ORGANIC GARLIC
# 13       45007            10076          ORGANIC ZUCCHINI
# 14       49683             9538            CUCUMBER KIRBY
# ...

# %% [markdown]
# Otra vez, son las frutas y verduras las que más se vuelven a pedir

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# C2 está completamente completado: filtrar `reordered == 1`, agregar los conteos de reorden, seleccionar el top 20 y hacer el merge con los nombres de productos produce exactamente la salida solicitada.
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
prop = order_products.groupby("product_id")["reordered"].mean().reset_index().rename(columns = {"reordered": "reorder_proportion"})

# %%
prop = prop.merge(products[["product_id", "product_name"]], on = "product_id")

# %%
print(prop[["product_id", "product_name", "reorder_proportion"]])
# Out:
#        product_id                                       product_name  \
# 0               1                         CHOCOLATE SANDWICH COOKIES
# 1               2                                   ALL-SEASONS SALT
# 2               3               ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3               4  SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4               7                     PURE COCONUT WATER WITH ORANGE
# ...           ...                                                ...
# 45568       49690                      HIGH PERFORMANCE ENERGY DRINK
# 45569       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 45570       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 45571       49693                             SPRING WATER BODY WASH
# 45572       49694                            BURRITO- STEAK & CHEESE
#
#        reorder_proportion
# 0                0.564286
# 1                0.000000
# 2                0.738095
# 3                0.510204
# ...

# %% [markdown]
# No se ha vuelto a pedir sal, y hay un gran "recompra" en bebida energetica y en te

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen método: tomar la media del flag `reordered` por `product_id` da correctamente la proporción de reorden, y hacer merge con `product_name` hace que los resultados sean más fáciles de interpretar.
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
orders_user = order_products.merge(orders[["order_id", "user_id"]], on = "order_id")

# %%
user_prop = (
    orders_user.groupby("user_id")["reordered"]
    .mean().reset_index(name="reorder_proportion"))

print(user_prop.head())
print(user_prop["reorder_proportion"].describe())
user_prop["reorder_proportion"].hist(bins=20)

plt.title("Distribución de la proporción de productos reordenados por cliente")
plt.xlabel("Proporción de productos reordenados")
plt.ylabel("Número de clientes")

plt.show()
# Out:
#    user_id  reorder_proportion
# 0        2            0.038462
# 1        4            0.000000
# 2        5            0.666667
# 3        6            0.000000
# 4        7            0.928571
# count    149626.000000
# mean          0.494853
# std           0.292685
# min           0.000000
# 25%           0.272727
# 50%           0.500000
# 75%           0.724138
# max           1.000000
# Name: reorder_proportion, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Imprimir la Series completa por usuario es abrumador y hace que el resultado sea difícil de verificar. Considera formatear la salida como un DataFrame con nombres de columna claros (p. ej., user_id y reorder_proportion), y reportar un resumen fácil de digerir (head/describe y/o un histograma) en lugar de imprimir cada fila.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Hay un pico cerca del 0, ya que tiene sentido que en las primeras compras (que ya vimos hay suficientes), sea la primera vez que las compran, fuera de eso, creo que puedo decir que la media es 0.5 (la mitad de los productos son reordenados)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Falta la explicación de las proporciones de recompra por cliente. Añade una breve interpretación de cómo se ve la distribución (valores típicos, dispersión y cualquier outlier/patrón destacable).
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
first_items = order_products[
    order_products["add_to_cart_order"] == 1
]

# %%
top_first = (
    first_items.groupby("product_id")["order_id"]
    .count()
    .sort_values(ascending=False)
    .head(20)
    .reset_index(name="times_first")
    .merge(
        products[["product_id", "product_name"]],
        on="product_id"
    )
)

# %%
print(top_first)
# Out:
#     product_id  times_first                 product_name
# 0        24852        15562                       BANANA
# 1        13176        11026       BAG OF ORGANIC BANANAS
# 2        27845         4363           ORGANIC WHOLE MILK
# 3        21137         3946         ORGANIC STRAWBERRIES
# 4        47209         3390         ORGANIC HASS AVOCADO
# 5        21903         3336         ORGANIC BABY SPINACH
# 6        47766         3044              ORGANIC AVOCADO
# 7        19660         2336                 SPRING WATER
# 8        16797         2308                 STRAWBERRIES
# 9        27966         2024          ORGANIC RASPBERRIES
# 10       44632         1914   SPARKLING WATER GRAPEFRUIT
# 11       49235         1797          ORGANIC HALF & HALF
# 12       47626         1737                  LARGE LEMON
# 13         196         1733                         SODA
# 14       38689         1397     ORGANIC REDUCED FAT MILK
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
# Los productos que primero ponene en sus carritos (los que probablemente les hagan abrir la aplicación). Son verduras y frutas. La primera es banana, que la han puesto como primer articulo más de 15 mil veces. El resto de productos siguen siendo productos alimenticios basicos, como agua y leche.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta sección de conclusiones sigue siendo el texto de plantilla. Añade una breve interpretación de los principales resultados de **‘first item in cart’** (qué tipos de productos aparecen con más frecuencia y cualquier patrón que observes).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# - Para el inciso C1, hiciste un correcto filtrado que permite observar de forma correcta como la cantidad de articulos por pedido oscila entre 7 y 10 articulos.
# - Para el inciso C2 hiciste un buen uso de `.merge` para encontrar como los productos mas reordenados.
# - En el punto C3 la tasa de repeticion por producto está correctamente calculada.
# - En el punto C4 hiciste un excelente uso de `groupby` para encontrar la tasa de repeticion por cliente.
# - En el punto C5 hiciste un excelente filtrado para encontrar los productos que las personas escogen de primero en sus carritos.

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Fue un proyecto realmente muy interesante. La limpieza me gusto, ya que pude identificar cuando podía eliminar información repetida, entre otras cosas. (Aun tengo duda en la ausencia de los nombres de los produuctos).
# El analisis sobre las horas de mayor demanda, el hecho de que no haya muchas segundas o más ordenes. Nos puede decir que la aplicación necesita mejorar. Y se deben implementar al mercado mas alimentos basicos, ya que son los que mayor demanda tienen.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu conclusión final está actualmente en una celda de código y no se lee como un resumen estructurado del proyecto. Considera moverla a una celda de markdown y resumir (1) las decisiones clave de limpieza de datos (duplicados, valores faltantes, tipos) y (2) los hallazgos principales de las secciones A/B/C en unas pocas oraciones claras.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Excelente conclusion! Has llegado al punto donde puedes nombrar las diferentes especificaciones del comportamiento de ventas de la empresa, y los hallazgos claves que señalas, como el hecho de que los usuarios tengan comportamientos periodicos y predecibles, dan mucho valor para la toma de decisiones. Te felicito por tu desempeño.
